# %% [markdown]
# <a href="https://colab.research.google.com/github/pacificspatial/flateau/blob/main/stac_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # STAC について学ぶ
# https://stacspec.org/en/tutorials/1-read-stac-python/
#
# https://pystac.readthedocs.io/en/stable/

# %%
! pip install pystac
# Out:
# Collecting pystac
#   Downloading pystac-1.10.1-py3-none-any.whl (182 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.9/182.9 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from pystac) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7.0->pystac) (1.16.0)
# Installing collected packages: pystac
# Successfully installed pystac-1.10.1

# %%
import json
import shutil
import tempfile
from pathlib import Path

from pystac import Catalog, get_stac_version
from pystac.extensions.eo import EOExtension
from pystac.extensions.label import LabelExtension

# %%
# Read the example catalog
root_catalog = Catalog.from_file('https://raw.githubusercontent.com/stac-utils/pystac/main/docs/example-catalog/catalog.json')

# %% [markdown]
# <h1>ハイレベルのカタログ情報の取得</h1>

# %%
root_catalog.describe()
# Out:
# * <Catalog id=landsat-stac-collection-catalog>
#     * <Collection id=landsat-8-l1>
#       * <Item id=LC80140332018166LGN00>
#       * <Item id=LC80150322018141LGN00>
#       * <Item id=LC80150332018189LGN00>
#       * <Item id=LC80300332018166LGN00>

# %% [markdown]
# このカタログには、Collectionが一つ、その下にItemが4つあることがわかる

# %%
# Print some basic metadata from the Catalog
print(f"ID: {root_catalog.id}")
print(f"Title: {root_catalog.title or 'N/A'}")
print(f"Description: {root_catalog.description or 'N/A'}")
# Out:
# ID: landsat-stac-collection-catalog
# Title: STAC for Landsat data
# Description: STAC for Landsat data

# %%
# check STAC version
print(get_stac_version())
# Out:
# 1.0.0

# %% [markdown]
# <h1> Collection について調べる </h1>

# %%
collections = list(root_catalog.get_collections())

print(f"Number of collections: {len(collections)}")
print("Collections IDs:")
for collection in collections:
    print(f"- {collection.id}")
# Out:
# Number of collections: 1
# Collections IDs:
# - landsat-8-l1

# %% [markdown]
# Collectionが一つで、IDは、landsat-8-11 であることがわかる
#
# 次にCollection ID を使ってCollectionインスタンスを取得する。

# %%
collection = root_catalog.get_child("landsat-8-l1")
if collection is None:
    print("Collection is Empty. Check your downloads and try agian.")
else:
    print("Collection has a root child. You may proceed to the following steps.")
# Out:
# Collection has a root child. You may proceed to the following steps.

# %% [markdown]
# <h1>STAC Itemについて学ぶ</h1>
# STAC Item は、カタログの基本構成要素。これが各データに対応するエントリーとなって、それらをOrganizeするのがCollection.で、Collectionを統合するのがCatalogで、Catalogが一番トップの要素となる。

# %%
items = list(root_catalog.get_all_items())

print(f"Number of items: {len(items)}")
for item in items:
    print(f"- {item.id}")
# Out:
# Number of items: 4
# - LC80140332018166LGN00
# - LC80150322018141LGN00
# - LC80150332018189LGN00
# - LC80300332018166LGN00

# %% [markdown]
# - Item のメタデータは、以下の構成になっている
#  - Core Item Metadata
#  - Common Metadata
#  - STAC Extensions
#
# item の id を使って、itemインスタンスを取得。

# %%
item = root_catalog.get_item("LC80140332018166LGN00", recursive=True)

# %% [markdown]
# 以下で、様々な属性を取り出してみる。

# %%
# ジオメトリ (Core Item)
item.geometry
# Out:
# {'type': 'Polygon',
#  'coordinates': [[[-76.12180471942207, 39.95810181489563],
#    [-73.94910518227414, 39.55117185146004],
#    [-74.49564725552679, 37.826064511480496],
#    [-76.66550404911956, 38.240699151776084],
#    [-76.12180471942207, 39.95810181489563]]]}

# %%
# BBOX (Core Item)
item.bbox
# Out:
# [-76.66703, 37.82561, -73.94861, 39.95958]

# %%
# date (Core Item)
item.datetime
# Out:
# datetime.datetime(2018, 6, 15, 15, 39, 9, tzinfo=tzutc())

# %%
# Collection ID (Core Item)
item.collection_id
# Out:
# 'landsat-8-l1'

# %%
# Item の属する Collection について知りたいなら (Core Item)
item.get_collection()
# Out:
# <Collection id=landsat-8-l1>

# %% [markdown]
# <h2>Comon Metadataについて</h2>
# データのライセンス、センサ、などの情報が格納されている

# %%
item.common_metadata.instruments
# Out:
# ['OLI_TIRS']

# %%
item.common_metadata.platform
# Out:
# 'landsat-8'

# %%
item.common_metadata.gsd
# Out:
# 30

# %% [markdown]
# <h2>STAC Extensionsについて</h2>
# CoreやCommonではカバーできないメタデータをこれでカバー

# %%
item.stac_extensions
# Out:
# ['https://stac-extensions.github.io/eo/v1.1.0/schema.json',
#  'https://stac-extensions.github.io/view/v1.0.0/schema.json',
#  'https://stac-extensions.github.io/projection/v1.1.0/schema.json']

# %%
EOExtension.has_extension(item)
# Out:
# True

# %%
LabelExtension.has_extension(item)
# Out:
# False

# %%
# Cloud coverage
eo_item_ext = EOExtension.ext(item)
eo_item_ext.cloud_cover
# Out:
# 22

# %%
# Cloud coverage 別の方法で取得
item.properties['eo:cloud_cover']
# Out:
# 22

# %% [markdown]
# <h1>STAC Item のアセットにアクセスするには</h1>
# ここでエられるデータで直接データにアクセス可能

# %%
for asset_key in item.assets:
    asset = item.assets[asset_key]
    print('{}: {} ({})'.format(asset_key, asset.href, asset.media_type))
# Out:
# index: https://s3-us-west-2.amazonaws.com/landsat-pds/c1/L8/014/033/LC08_L1TP_014033_20180615_20180703_01_T1/index.html (text/html)
# thumbnail: https://s3-us-west-2.amazonaws.com/landsat-pds/c1/L8/014/033/LC08_L1TP_014033_20180615_20180703_01_T1/LC08_L1TP_014033_20180615_20180703_01_T1_thumb_large.jpg (image/jpeg)
# B1: https://s3-us-west-2.amazonaws.com/landsat-pds/c1/L8/014/033/LC08_L1TP_014033_20180615_20180703_01_T1/LC08_L1TP_014033_20180615_20180703_01_T1_B1.TIF (image/tiff)
# B2: https://s3-us-west-2.amazonaws.com/landsat-pds/c1/L8/014/033/LC08_L1TP_014033_20180615_20180703_01_T1/LC08_L1TP_014033_20180615_20180703_01_T1_B2.TIF (image/tiff)
# B3: https://s3-us-west-2.amazonaws.com/landsat-pds/c1/L8/014/033/LC08_L1TP_014033_20180615_20180703_01_T1/LC08_L1TP_014033_20180615_20180703_01_T1_B3.TIF (image/tiff)
# B4: https://s3-us-west-2.amazonaws.com/landsat-pds/c1/L8/014/033/LC08_L1TP_014033_20180615_20180703_01_T1/LC08_L1TP_014033_20180615_20180703_01_T1_B4.TIF (image/tiff)
# B5: https://s3-us-west-2.amazonaws.com/landsat-pds/c1/L8/014/033/LC08_L1TP_014033_20180615_20180703_01_T1/LC08_L1TP_014033_20180615_20180703_01_T1_B5.TIF (image/tiff)
# B6: https://s3-us-west-2.amazonaws.com/landsat-pds/c1/L8/014/033/LC08_L1TP_014033_20180615_20180703_01_T1/LC08_L1TP_014033_20180615_20180703_01_T1_B6.TIF (image/tiff)
# B7: https://s3-us-west-2.amazonaws.com/landsat-pds/c1/L8/014/033/LC08_L1TP_014033_20180615_20180703_01_T1/LC08_L1TP_014033_20180615_20180703_01_T1_B7.TIF (image/tiff)
# B8: https://s3-us-west-2.amazonaws.com/landsat-pds/c1/L8/014/033/LC08_L1TP_014033_20180615_20180703_01_T1/LC08_L1TP_014033_20180615_20180703_01_T1_B8.TIF (image/tiff)
# B9: https://s3-us-west-2.amazonaws.com/landsat-pds/c1/L8/014/033/LC08_L1TP_014033_20180615_20180703_01_T1/LC08_L1TP_014033_20180615_20180703_01_T1_B9.TIF (image/tiff)
# B10: https://s3-us-west-2.amazonaws.com/landsat-pds/c1/L8/014/033/LC08_L1TP_014033_20180615_20180703_01_T1/LC08_L1TP_014033_20180615_20180703_01_T1_B10.TIF (image/tiff)
# B11: https://s3-us-west-2.amazonaws.com/landsat-pds/c1/L8/014/033/LC08_L1TP_014033_20180615_20180703_01_T1/LC08_L1TP_014033_20180615_20180703_01_T1_B11.TIF (image/tiff)
# ANG: https://s3-us-west-2.amazonaws.com/landsat-pds/c1/L8/014/033/LC08_L1TP_014033_20180615_20180703_01_T1/LC08_L1TP_014033_20180615_20180703_01_T1_ANG.txt (text/plain)
# MTL: https://s3-us-west-2.amazonaws.com/landsat-pds/c1/L8/014/033/LC08_L1TP_014033_20180615_20180703_01_T1/LC08_L1TP_014033_20180615_20180703_01_T1_MTL.txt (text/plain)
# BQA: https://s3-us-west-2.amazonaws.com/landsat-pds/c1/L8/014/033/LC08_L1TP_014033_20180615_20180703_01_T1/LC08_L1TP_014033_20180615_20180703_01_T1_BQA.TIF (image/tiff)

# %%
asset = item.assets['B3']
asset.to_dict()
# Out:
# {'href': 'https://s3-us-west-2.amazonaws.com/landsat-pds/c1/L8/014/033/LC08_L1TP_014033_20180615_20180703_01_T1/LC08_L1TP_014033_20180615_20180703_01_T1_B3.TIF',
#  'type': 'image/tiff',
#  'title': 'Band 3 (green)',
#  'eo:bands': [{'name': 'B3',
#    'full_width_half_max': 0.06,
#    'center_wavelength': 0.56,
#    'common_name': 'green'}],
#  'roles': []}

# %%
eo_asset_ext = EOExtension.ext(asset)
bands = eo_asset_ext.bands
bands
# Out:
# [<Band name=B3>]

# %%
bands[0].to_dict()
# Out:
# {'name': 'B3',
#  'full_width_half_max': 0.06,
#  'center_wavelength': 0.56,
#  'common_name': 'green'}

# %% [markdown]
# <h1>STAC Catalogを作るには</h1>

# %%
# 必要なライブラリを読む
#! pip install pystac
! pip install rasterio
#! pip install shapely
# Out:
# Collecting rasterio
#   Downloading rasterio-1.3.10-cp310-cp310-manylinux2014_x86_64.whl (21.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 38.1 MB/s eta 0:00:00
# Collecting affine (from rasterio)
#   Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from rasterio) (23.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from rasterio) (2024.2.2)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.10/dist-packages (from rasterio) (8.1.7)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.25.2)
# Collecting snuggs>=1.4.1 (from rasterio)
#   Downloading snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.10/dist-packages (from rasterio) (1.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from rasterio) (67.7.2)
# Requirement already satisfied: pyparsing>=2.1.6 in /usr/local/lib/python3.10/dist-packages (from snuggs>=1.4.1->rasterio) (3.1.2)
# Installing collected packages: snuggs, affine, rasterio
# Successfully installed affine-2.4.0 rasterio-1.3.10 snuggs-1.4.7

# %%
import os
import json
import rasterio
import urllib.request
import pystac

from datetime import datetime, timezone
from shapely.geometry import Polygon, mapping
from tempfile import TemporaryDirectory

# %%
# サンプルデータをダウンロード　(/content/SN5_roads_train_AOI_7_Moscow_MS_chip996.tif として格納される)
# !wget https://spacenet-dataset.s3.amazonaws.com/spacenet/SN5_roads/train/AOI_7_Moscow/MS/SN5_roads_train_AOI_7_Moscow_MS_chip996.tif
# Out:
# --2024-05-13 03:33:03--  https://spacenet-dataset.s3.amazonaws.com/spacenet/SN5_roads/train/AOI_7_Moscow/MS/SN5_roads_train_AOI_7_Moscow_MS_chip996.tif
# Resolving spacenet-dataset.s3.amazonaws.com (spacenet-dataset.s3.amazonaws.com)... 3.5.28.218, 3.5.25.132, 52.217.132.121, ...
# Connecting to spacenet-dataset.s3.amazonaws.com (spacenet-dataset.s3.amazonaws.com)|3.5.28.218|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1693036 (1.6M) [image/tiff]
# Saving to: ‘SN5_roads_train_AOI_7_Moscow_MS_chip996.tif’
#
# SN5_roads_train_AOI 100%[===================>]   1.61M  9.09MB/s    in 0.2s
#
# 2024-05-13 03:33:04 (9.09 MB/s) - ‘SN5_roads_train_AOI_7_Moscow_MS_chip996.tif’ saved [1693036/1693036]

# %% [markdown]
# <h2>STAC Catlog を作る</h2>
# id と description は必須。まずはそれだけでOK。

# %%
catalog = pystac.Catalog(id='tutorial-catalog', description='デモ用カタログ with SpaceNet 5.')

# %% [markdown]
# まだ何も追加していないのでカラ。

# %%
print(list(catalog.get_children()))
print(list(catalog.get_items()))
# Out:
# []
# []

# %% [markdown]
# 以下のコマンドを叩くと、JSONが作られていく様子を確認できる。

# %%
print(json.dumps(catalog.to_dict(), indent=4))
# Out:
# {
#     "type": "Catalog",
#     "id": "tutorial-catalog",
#     "stac_version": "1.0.0",
#     "description": "\u30c7\u30e2\u7528\u30ab\u30bf\u30ed\u30b0 with SpaceNet 5.",
#     "links": []
# }

# %%
# サンプルのラスタデータをItemとして追加するために、geometry と bbox を作成する関数を作成
def get_bbox_and_footprint(raster):
    with rasterio.open(raster) as r:
        bounds = r.bounds
        bbox = [bounds.left, bounds.bottom, bounds.right, bounds.top]
        footprint = Polygon([
            [bounds.left, bounds.bottom],
            [bounds.left, bounds.top],
            [bounds.right, bounds.top],
            [bounds.right, bounds.bottom]
        ])

        return (bbox, mapping(footprint))

# %%
# 実際に関数を使ってGeometryとBBOXを取得
bbox, footprint = get_bbox_and_footprint('/content/SN5_roads_train_AOI_7_Moscow_MS_chip996.tif')
print("bbox: ", bbox, "\n")
print("footprint: ", footprint)
# Out:
# bbox:  [37.6616853489879, 55.73478197572927, 37.66573047610874, 55.73882710285011]
#
# footprint:  {'type': 'Polygon', 'coordinates': (((37.6616853489879, 55.73478197572927), (37.6616853489879, 55.73882710285011), (37.66573047610874, 55.73882710285011), (37.66573047610874, 55.73478197572927), (37.6616853489879, 55.73478197572927)),)}

# %%
# タイムスタンプを作成
datetime_utc = datetime.now(tz=timezone.utc)

# %% [markdown]
# <h3>Itemの作成</h3>
#
#
# *   id
# *   geometry
# *   bbox
# *   datetime
# *   properties

# %%
item = pystac.Item(id='local-image',
                 geometry=footprint,
                 bbox=bbox,
                 datetime=datetime_utc,
                 properties={})

# %%
print(item.get_parent() is None)
# Out:
# True

# %%
# ここでカタログにItemを追加する
catalog.add_item(item)
# Out:
# <Link rel=item target=<Item id=local-image>>

# %%
# カタログを確認
item.get_parent()
# Out:
# <Catalog id=tutorial-catalog>

# %%
# 以下でもカタログの構造を確認できる
catalog.describe()
# Out:
# * <Catalog id=tutorial-catalog>
#   * <Item id=local-image>

# %% [markdown]
# <h2>STAC Asset (つまりデータそのものの情報) を追加</h2>
# ここまででItemは作成してCatalogに追加しているが、実際のアセットはItemに対してついかされていない。ここで追加する。
#
# https://pystac.readthedocs.io/en/stable/api/asset.html#pystac-asset
#
# すでに作成済みの item に対して asset を追加するが、key と asset を指定する。
#
# asset では、href, media_type を指定している。
# media_type としてGeoTIFFを指定しているが他のタイプも有る。
#
# https://pystac.readthedocs.io/en/stable/api/media_type.html
#
# ベクタ系では、parquet, kml, geojson, geopackage, flatgeobuf 等がある。

# %%
# Add Asset and all its information to Item
item.add_asset(
    key='image',
    asset=pystac.Asset(
        href='/content/SN5_roads_train_AOI_7_Moscow_MS_chip996.tif',
        media_type=pystac.MediaType.GEOTIFF
    )
)

# %%
print(json.dumps(item.to_dict(), indent=4))
# Out:
# {
#     "type": "Feature",
#     "stac_version": "1.0.0",
#     "id": "local-image",
#     "properties": {
#         "datetime": "2024-05-13T03:33:14.468410Z"
#     },
#     "geometry": {
#         "type": "Polygon",
#         "coordinates": [
#             [
#                 [
#                     37.6616853489879,
#                     55.73478197572927
#                 ],
#                 [
#                     37.6616853489879,
#                     55.73882710285011
#                 ],
#                 [
#                     37.66573047610874,
#                     55.73882710285011
#                 ],
#                 [
#                     37.66573047610874,
#                     55.73478197572927
#                 ],
#                 [
#                     37.6616853489879,
#                     55.73478197572927
#                 ]
#             ]
#         ]
#     },
#     "links": [
#         {
#             "rel": "root",
#             "href": null,
#             "type": "application/json"
#         },
#         {
#             "rel": "parent",
#             "href": null,
#             "type": "application/json"
#         }
#     ],
#     "assets": {
#         "image": {
#             "href": "/content/SN5_roads_train_AOI_7_Moscow_MS_chip996.tif",
#             "type": "image/tiff; application=geotiff"
#         }
#     },
#     "bbox": [
#         37.6616853489879,
#         55.73478197572927,
#         37.66573047610874,
#         55.73882710285011
#     ],
#     "stac_extensions": []
# }

# %% [markdown]
# <h1>カタログを保存</h1>
#
# 今のところカタログ自体のhrefは設定されていない

# %%
print(catalog.get_self_href() is None)
print(item.get_self_href() is None)
# Out:
# True
# True

# %% [markdown]
# カタログのHREFを設定する

# %%
catalog.normalize_hrefs(os.path.join('/content/sample_data', "stac"))

# %%
print("Catalog HREF: ", catalog.get_self_href())
print("Item HREF: ", item.get_self_href())
# Out:
# Catalog HREF:  /content/sample_data/stac/catalog.json
# Item HREF:  /content/sample_data/stac/local-image/local-image.json

# %% [markdown]
# <h2>カタログの保存</h2>

# %%
catalog.save(catalog_type=pystac.CatalogType.SELF_CONTAINED)

# %%
# !ls /content/sample_data/stac/*
# Out:
# /content/sample_data/stac/catalog.json
#
# /content/sample_data/stac/local-image:
# local-image.json

# %%
with open(catalog.self_href) as f:
    print(f.read())
# Out:
# {
#   "type": "Catalog",
#   "id": "tutorial-catalog",
#   "stac_version": "1.0.0",
#   "description": "\u30c7\u30e2\u7528\u30ab\u30bf\u30ed\u30b0 with SpaceNet 5.",
#   "links": [
#     {
#       "rel": "root",
#       "href": "./catalog.json",
#       "type": "application/json"
#     },
#     {
#       "rel": "item",
#       "href": "./local-image/local-image.json",
#       "type": "application/json"
#     }
#   ]
# }

# %%
with open(item.self_href) as f:
    print(f.read())
# Out:
# {
#   "type": "Feature",
#   "stac_version": "1.0.0",
#   "id": "local-image",
#   "properties": {
#     "datetime": "2024-05-13T03:33:14.468410Z"
#   },
#   "geometry": {
#     "type": "Polygon",
#     "coordinates": [
#       [
#         [
#           37.6616853489879,
#           55.73478197572927
#         ],
#         [
#           37.6616853489879,
#           55.73882710285011
#         ],
#         [
#           37.66573047610874,
#           55.73882710285011
#         ],
#         [
#           37.66573047610874,
#           55.73478197572927
#         ],
#         [
#           37.6616853489879,
#           55.73478197572927
#         ]
#       ]
#     ]
#   },
#   "links": [
#     {
#       "rel": "root",
#       "href": "../catalog.json",
#       "type": "application/json"
#     },
#     {
#       "rel": "parent",
#       "href": "../catalog.json",
#       "type": "application/json"
#     }
#   ],
#   "assets": {
#     "image": {
#       "href": "/content/SN5_roads_train_AOI_7_Moscow_MS_chip996.tif",
#       "type": "image/tiff; application=geotiff"
#     }
#   },
#   "bbox": [
#     37.6616853489879,
#     55.73478197572927,
#     37.66573047610874,
#     55.73882710285011
#   ],
#   "stac_extensions": []
# }

# %% [markdown]
# <h1>Flateauのカタログを作ってみる</h1>

# %%
import pandas as pd
import geopandas as gpd
import uuid

# %%
catalog = pystac.Catalog(id='flateau-catalog', description='flateau catalog')

# %% [markdown]
# ジオメトリとBBOXが必要

# %%
stac_file = r'/content/stac_items.csv'
stac_df = pd.read_csv(stac_file)
stac_df.head()
# Out:
#                                            _filename  \
# 0  01100_sapporo-shi_2020_building_centroid_lod0....
# 1  01205_muroran-shi_2022_building_centroid_lod0....
# 2  01100_sapporo-shi_2020_building_centroid_lod0....
# 3  01205_muroran-shi_2022_building_centroid_lod0....
# 4  01639_sarabetsu-mura_2023_building_centroid_lo...
#
#                                                  url       _xmin       _xmax  \
# 0  https://data.source.coop/pacificspatial/flatea...  141.119971  141.505164
# 1  https://data.source.coop/pacificspatial/flatea...  140.908458  141.048746
# 2  https://data.source.coop/pacificspatial/flatea...  141.119971  141.505164
# 3  https://data.source.coop/pacificspatial/flatea...  140.908458  141.048746
# 4  https://data.source.coop/pacificspatial/flatea...  143.104780  143.304112
#
#        _ymin      _ymax
# 0  42.896122  43.184199
# 1  42.302084  42.420657
# 2  42.896122  43.184199
# 3  42.302084  42.420657
# 4  42.571978  42.720527

# %%
for index, row in stac_df.iterrows():

  bbox = [row._xmin, row._ymin, row._xmax, row._ymax]
  footprint = Polygon([
      [row._xmin, row._ymin],
      [row._xmin, row._ymax],
      [row._xmax, row._ymax],
      [row._xmax, row._ymin]
  ])

  item = pystac.Item(id=row._filename,
    geometry=mapping(footprint),
    bbox=bbox,
    datetime=datetime.now(tz=timezone.utc),
    properties={})

  # add an item to the catalog
  catalog.add_item(item)

  # Add Asset and all its information to Item
  item.add_asset(
    key=str(uuid.uuid4()),
    asset=pystac.Asset(
      href=row.url,
      media_type=pystac.MediaType.PARQUET
    )
  )



  print('added one item')
# Out:
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item
# added one item

# %%
# カタログを確認
item.get_parent()
# Out:
# <Catalog id=flateau-catalog>

# %%
item
# Out:
# <Item id=47201_naha-shi_2020_building_centroid_lod0.parquet>

# %%
catalog.normalize_hrefs(os.path.join('/content/sample_data', "stac"))

# %%
print("Catalog HREF: ", catalog.get_self_href())
print("Item HREF: ", item.get_self_href())
# Out:
# Catalog HREF:  /content/sample_data/stac/catalog.json
# Item HREF:  /content/sample_data/stac/47201_naha-shi_2020_building_centroid_lod0.parquet/47201_naha-shi_2020_building_centroid_lod0.parquet.json

# %%
catalog.save(catalog_type=pystac.CatalogType.SELF_CONTAINED)

# %%
with open(catalog.self_href) as f:
    print(f.read())
# Out:
# {
#   "type": "Catalog",
#   "id": "flateau-catalog",
#   "stac_version": "1.0.0",
#   "description": "flateau catalog",
#   "links": [
#     {
#       "rel": "root",
#       "href": "./catalog.json",
#       "type": "application/json"
#     },
#     {
#       "rel": "item",
#       "href": "./01100_sapporo-shi_2020_building_centroid_lod0.parquet/01100_sapporo-shi_2020_building_centroid_lod0.parquet.json",
#       "type": "application/json"
#     },
#     {
#       "rel": "item",
#       "href": "./01205_muroran-shi_2022_building_centroid_lod0.parquet/01205_muroran-shi_2022_building_centroid_lod0.parquet.json",
#       "type": "application/json"
#     },
#     {
#       "rel": "item",
#       "href": "./01100_sapporo-shi_2020_building_centroid_lod0.parquet/01100_sapporo-shi_2020_building_centroid_lod0.parquet.json",
#       "type": "application/json"
#     },
#     {
#       "rel": "item",
#       "href": "./01205_muroran-shi_2022_building_centroid_lod0.parquet/01205_muroran-shi_2022_building_centroid_lod0.parquet.json",
#       "type": "application/json"
#     },
#     {
#       "rel": "item",
#       "href": "./01639_sarabetsu-mura_2023_building_centroid_lod0.parquet/01639_sarabetsu-mura_2023_building_centroid_lod0.parquet.json",
#       "type": "application/json"
#     },
#     {
#       "rel": "item",
#       "href": "./02208_mutsu-shi_2022_building_centroid_lod0.parquet/02208_mutsu-shi_2022_building_centroid_lod0.parquet.json",
#       "type": "application/json"
#     },
#     {
#       "rel": "item",
#       "href": "./03201_morioka-shi_2023_building_centroid_lod0.parquet/03201_morioka-shi_2023_building_centroid_lod0.parquet.json",
#       "type": "application/json"
#     },
#     {
#       "rel": "item",
#       "href": "./02208_mutsu-shi_2022_building_centroid_lod0.parquet/02208_mutsu-shi_2022_building_centroid_lod0.parquet.json",
#       "type": "application/json"
#     },
#     {
#       "rel": "item",
#       "href": "./03201_morioka-shi_2023_building_centroid_lod0.parquet/03201_morioka-shi_2023_building_centroid_lod0.parquet.json",
#       "type": "application/json"
#     },
#     {
#       "rel": "item",
#       "href": "./04100_sendai-shi_2022_building_centroid_lod0.parquet/04100_sendai-shi_2022_building_centroid_lod0.parquet.json",
#       "type": "application/json"
#     },
#     {
#       "rel": "item",
#       "href": "./07203_koriyama-shi_2020_building_centroid_lod0.parquet/07203_koriyama-shi_2020_building_centroid_lod0.parquet.json",
#       "type": "application/json"
#     },
#     {
#       "rel": "item",
#       "href": "./07204_iwaki-shi_2020_building_centroid_lod0.parquet/07204_iwaki-shi_2020_building_centroid_lod0.parquet.json",
#       "type": "application/json"
#     },
#     {
#       "rel": "item",
#       "href": "./07205_shirakawa-shi_2020_building_centroid_lod0.parquet/07205_shirakawa-shi_2020_building_centroid_lod0.parquet.json",
#       "type": "application/json"
#     },
#     {
#       "rel": "item",
#       "href": "./07212_minamisoma-shi_2022_building_centroid_lod0.parquet/07212_minamisoma-shi_2022_building_centroid_lod0.parquet.json",
#       "type": "application/json"
#     },
#     {
#       "rel": "item",
#       "href": "./08220_tsukuba-shi_2023_building_centroid_lod0.parquet/08220_tsukuba-shi_2023_building_centroid_lod0.parquet.json",
#       "type": "application/json"
#     },
#     {
#       "rel": "item",
#       "href": "./08234_hokota-shi_2022_building_centroid_lod0.parquet/08234_hokota-shi_2022_building_centroid_lod0.parquet.json",
#       "type": "application/json"
#     },
#     {
#       "rel": "item",
#       "href": "./08546_sakai-machi_2023_building_centroid_lod0.parquet/08546_sakai-machi_2023_building_centroid_lod0.parquet.json",
#       "type": "application/json"
#     },
#     {
#       "rel": "item",
#       "href": "./09201_utsunomiya-shi_2023_building_centroid_lod0.parquet/09201_utsunomiya-shi_2023_building_centroid_lod0.parquet.json",
#       "type": "application/json"
#     },
#     {
#       "rel": "item",
#       "href": "./10201_maebashi-shi_2023_building_centroid_lod0.parquet/10201_maebashi-shi_2023_building_centroid_lod0.parquet.json",
#       "type": "application/json"
#     },
#     {
#       "rel": "item",
#       "href": "
building_centroid_lod0.parquet.json",
#       "type": "application/json"
#     },
#     {
#       "rel": "item",
#       "href": "./47201_naha-shi_2020_building_centroid_lod0.parquet/47201_naha-shi_2020_building_centroid_lod0.parquet.json",
#       "type": "application/json"
#     }
#   ]
# }

# %%
with open(item.self_href) as f:
    print(f.read())
# Out:
# {
#   "type": "Feature",
#   "stac_version": "1.0.0",
#   "id": "47201_naha-shi_2020_building_centroid_lod0.parquet",
#   "properties": {
#     "datetime": "2024-05-13T04:35:58.462774Z"
#   },
#   "geometry": {
#     "type": "Polygon",
#     "coordinates": [
#       [
#         [
#           127.63998422337508,
#           26.17658338710737
#         ],
#         [
#           127.63998422337508,
#           26.24653602356476
#         ],
#         [
#           127.73870144544492,
#           26.24653602356476
#         ],
#         [
#           127.73870144544492,
#           26.17658338710737
#         ],
#         [
#           127.63998422337508,
#           26.17658338710737
#         ]
#       ]
#     ]
#   },
#   "links": [
#     {
#       "rel": "root",
#       "href": "../catalog.json",
#       "type": "application/json"
#     },
#     {
#       "rel": "parent",
#       "href": "../catalog.json",
#       "type": "application/json"
#     }
#   ],
#   "assets": {
#     "c0d312d1-b564-4b79-a440-4a5271b62965": {
#       "href": "https://data.source.coop/pacificspatial/flateau/parquet/47201_naha-shi_2020_building_centroid_lod0.parquet",
#       "type": "application/x-parquet"
#     }
#   },
#   "bbox": [
#     127.63998422337508,
#     26.17658338710737,
#     127.73870144544492,
#     26.24653602356476
#   ],
#   "stac_extensions": []
# }

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/sample_data
# Out:
# /content/sample_data

# %%
# !zip -r stac.zip stac/
# Out:
#   adding: stac/ (stored 0%)
#   adding: stac/22216_fukuroi-shi_2023_building_centroid_lod0.parquet/ (stored 0%)
#   adding: stac/22216_fukuroi-shi_2023_building_centroid_lod0.parquet/22216_fukuroi-shi_2023_building_centroid_lod0.parquet.json (deflated 64%)
#   adding: stac/22461_mori-machi_2023_building_centroid_lod0.parquet/ (stored 0%)
#   adding: stac/22461_mori-machi_2023_building_centroid_lod0.parquet/22461_mori-machi_2023_building_centroid_lod0.parquet.json (deflated 64%)
#   adding: stac/22342_nagaizumi-cho_2023_building_centroid_lod0.parquet/ (stored 0%)
#   adding: stac/22342_nagaizumi-cho_2023_building_centroid_lod0.parquet/22342_nagaizumi-cho_2023_building_centroid_lod0.parquet.json (deflated 64%)
#   adding: stac/34207_fukuyama-shi_2020_building_centroid_lod0.parquet/ (stored 0%)
#   adding: stac/34207_fukuyama-shi_2020_building_centroid_lod0.parquet/34207_fukuyama-shi_2020_building_centroid_lod0.parquet.json (deflated 65%)
#   adding: stac/22220_susono-shi_2023_building_centroid_lod0.parquet/ (stored 0%)
#   adding: stac/22220_susono-shi_2023_building_centroid_lod0.parquet/22220_susono-shi_2023_building_centroid_lod0.parquet.json (deflated 64%)
#   adding: stac/13207_akishima-shi_2023_building_centroid_lod0.parquet/ (stored 0%)
#   adding: stac/13207_akishima-shi_2023_building_centroid_lod0.parquet/13207_akishima-shi_2023_building_centroid_lod0.parquet.json (deflated 65%)
#   adding: stac/23230_nisshin-shi_2023_building_centroid_lod0.parquet/ (stored 0%)
#   adding: stac/23230_nisshin-shi_2023_building_centroid_lod0.parquet/23230_nisshin-shi_2023_building_centroid_lod0.parquet.json (deflated 65%)
#   adding: stac/41423_omachi-cho_2022_building_centroid_lod0.parquet/ (stored 0%)
#   adding: stac/41423_omachi-cho_2022_building_centroid_lod0.parquet/41423_omachi-cho_2022_building_centroid_lod0.parquet.json (deflated 65%)
#   adding: stac/26100_kyoto-shi_2023_building_centroid_lod0.parquet/ (stored 0%)
#   adding: stac/26100_kyoto-shi_2023_building_centroid_lod0.parquet/26100_kyoto-shi_2023_building_centroid_lod0.parquet.json (deflated 64%)
#   adding: stac/13122_katsushika-ku_2023_building_centroid_lod0.parquet/ (stored 0%)
#   adding: stac/13122_katsushika-ku_2023_building_centroid_lod0.parquet/13122_katsushika-ku_2023_building_centroid_lod0.parquet.json (deflated 64%)
#   adding: stac/40205_iizuka-shi_2020_building_centroid_lod0.parquet/ (stored 0%)
#   adding: stac/40205_iizuka-shi_2020_building_centroid_lod0.parquet/40205_iizuka-shi_2020_building_centroid_lod0.parquet.json (deflated 65%)
#   adding: stac/01205_muroran-shi_2022_building_centroid_lod0.parquet/ (stored 0%)
#   adding: stac/01205_muroran-shi_2022_building_centroid_lod0.parquet/01205_muroran-shi_2022_building_centroid_lod0.parquet.json (deflated 65%)
#   adding: stac/23207_toyokawa-shi_2022_building_centroid_lod0.parquet/ (stored 0%)
#   adding: stac/23207_toyokawa-shi_2022_building_centroid_lod0.parquet/23207_toyokawa-shi_2022_building_centroid_lod0.parquet.json (deflated 64%)
#   adding: stac/09201_utsunomiya-shi_2023_building_centroid_lod0.parquet/ (stored 0%)
#   adding: stac/09201_utsunomiya-shi_2023_building_centroid_lod0.parquet/09201_utsunomiya-shi_2023_building_centroid_lod0.parquet.json (deflated 64%)
#   adding: stac/13219_komae-shi_2023_building_centroid_lod0.parquet/ (stored 0%)
#   adding: stac/13219_komae-shi_2023_building_centroid_lod0.parquet/13219_komae-shi_2023_building_centroid_lod0.parquet.json (deflated 65%)
#   adding: stac/11222_koshigaya-shi_2023_building_centroid_lod0.parquet/ (stored 0%)
#   adding: stac